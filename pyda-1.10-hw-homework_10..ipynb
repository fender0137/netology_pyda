# %% [markdown]
# *Задание 1*
#
# Скачайте с сайта https://grouplens.org/datasets/movielens/ датасет любого размера. Определите какому фильму было выставлено больше всего оценок 5.0.

# %%
import pandas as pd

# %%
rating = pd.read_csv('ratings.csv')
movies = pd.read_csv('movies.csv')


print(rating.head(10))
movies.head(10)
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931
# 5       1       70     3.0  964982400
# 6       1      101     5.0  964980868
# 7       1      110     4.0  964982176
# 8       1      151     5.0  964984041
# 9       1      157     5.0  964984100
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
# 5        6                         Heat (1995)
# 6        7                      Sabrina (1995)
# 7        8                 Tom and Huck (1995)
# 8        9                 Sudden Death (1995)
# 9       10                    GoldenEye (1995)
#
# ...

# %%
data = pd.merge(rating, movies, left_on='movieId', right_on='movieId', how='left').sort_values(by='rating',ascending=False)

# %%
raiting_films = data.filter(items = ['rating', 'title'])
films_5 = raiting_films[(raiting_films['rating']==5)]

# %%
count_5_stars_film = films_5.groupby('title').count()
count_5_stars_film.sort_values('rating',ascending=False).head(1)
# Out:
#                                   rating
# title
# Shawshank Redemption, The (1994)     153

# %% [markdown]
# *Задание 2*
#
# По данным файла power.csv посчитайте суммарное потребление стран Прибалтики (Латвия, Литва и Эстония) категорий 4, 12 и 21 за период с 2005 по 2010 года. Не учитывайте в расчетах отрицательные значения quantity.

# %%
power = pd.read_csv('power.csv')
power.head(10)
country_films = power[(power['year']>=2005) & (power['year']<=2010) & (power['quantity']>0) &
                      ((power['category']==4) | (power['category']==12) | (power['category']==21))
                     & ((power['country']=='Lithuania')|(power['country']=='Latvia')|(power['country']=='Estonia'))]
country_films
# Out:
#           country  year  quantity  category
# 10617     Estonia  2008       1.0         4
# 10620     Estonia  2005       1.0         4
# 11156   Lithuania  2008       1.0         4
# 11158   Lithuania  2006       1.0         4
# 11159   Lithuania  2005       1.0         4
# 12755     Estonia  2008       1.0         4
# 12758     Estonia  2005       1.0         4
# 13294   Lithuania  2008       1.0         4
# 13296   Lithuania  2006       1.0         4
# 13297   Lithuania  2005       1.0         4
# 15525     Estonia  2008       1.0         4
# 15528     Estonia  2005       1.0         4
# 16068   Lithuania  2008       1.0         4
# 16070   Lithuania  2006       1.0         4
# 16071   Lithuania  2005       1.0         4
# 17675     Estonia  2008       1.0         4
# 17678     Estonia  2005       1.0         4
# 18218   Lithuania  2008       1.0         4
# 18220   Lithuania  2006       1.0         4
# 18221   Lithuania  2005       1.0         4
# ...

# %%
country_films.filter(items = ['quantity']).sum()
# Out:
# quantity    240580.0
# dtype: float64

# %% [markdown]
# *Задание 3*
#
# Выберите страницу любого сайта с табличными данными. Импортируйте таблицы в pandas dataframe.
# Примеры страниц (необязательно брать именно эти):
# https://fortrader.org/quotes
# https://www.finanz.ru/valyuty/v-realnom-vremeni

# %%
page_url = 'https://fortrader.org/quotes'
df = pd.read_html(page_url,  encoding='utf-8')
df
# Out:
# [                               Type    Last   Chg.  Chg.%  Time
#  0  Нефть (BRENT) Курс нефти сегодня  62.480  0.610  0.990   NaN
#  1   Нефть (WTI) Цены на нефть (WTI)  57.170  0.530  0.940   NaN
#  2          Сахар котировки на сахар  12.630  0.000  0.000   NaN
#  3                   Газ Цена на газ   2.645 -0.142 -5.095   NaN,
#                                      Type          Last      Chg.     Chg.%  \
#  0                      ВТБ Акции ОАО ВТБ       0.04779  +0.00497  11.60673
#  1                 Газпром Акции газпрома     262.70000    +20.83   8.61000
#  2                    Лукоил Акции Лукойл    6078.50000     -17.0  -0.30000
#  3                Роснефть Акции Роснефти     464.30000    +43.05  10.22000
#  4               Сбербанк Акции Сбербанка     242.51000     +1.36   0.56000
#  5   Сургутнефтегаз Акции Сургутнефтегаза      49.54000    +7.925  19.04400
#  6              Норникель Акции Норникель   17672.00000      -982  -5.00000
# ...

# %%
type(df[1])
# Out:
# pandas.core.frame.DataFrame
